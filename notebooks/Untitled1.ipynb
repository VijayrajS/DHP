# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %%
options = Options()
options.binary_location = "/bin/chromium"
driver = webdriver.Chrome(chrome_options=options, executable_path='/run/media/badwolf/Windows/Users/Urja Nadibail/acads/chromedriver')
# Out:
# /home/badwolf/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: use options instead of chrome_options
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
articles = []

# %%
driver.get('https://timesofindia.indiatimes.com/topic/citizenship-amendment-act/news')
while next_page:
    c = driver.find_elements_by_class_name('article')
    for i in c:
        d = {}
        d['url'] = i.find_element_by_class_name('content').find_element_by_tag_name("a").get_attribute("href")
        d['title'] = i.find_element_by_class_name('content').find_element_by_class_name("title").text
        d['date'] = i.find_element_by_class_name('content').find_element_by_class_name("meta").get_attribute("rodate")
        articles.append(d)
    next_page = driver.find_element_by_id('raquo')
    next_page.click()
# Out:
# ----------------------------------------------
# TypeError    Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-77-4b30597e8581> in <module>
#       4     for i in c:
#       5         d = {}
# ----> 6         d['url'] = i.find_element_by_class_name('content').find_element_by_tag_name("a").get_attribute("href")
#       7         d['title'] = i.find_element_by_class_name('content').find_element_by_class_name("title").text
# ...

# %%
dates = []
for i in uniq:
    if i['date']:
        dates.append(i['date'])

# %%
uniq
# Out:
# [{'url': 'https://timesofindia.indiatimes.com/city/chandigarh/dhindsa-sad-failed-its-ideology-on-caa-abrogation-of-art-370/articleshow/73163828.cms',
#   'title': 'Dhindsa: SAD failed its ideology on CAA, abrogation of Art 370',
#   'date': '2020-01-09T02:09:00Z'},
#  {'url': 'https://timesofindia.indiatimes.com/city/chandigarh/bjp-will-have-to-pay-heavy-price-for-stubborness-on-caa-amarinder/articleshow/73163897.cms',
#   'title': 'BJP will have to pay heavy price for stubborness on CAA: Amarinder',
#   'date': '2020-01-09T02:09:00Z'},
#  {'url': 'https://timesofindia.indiatimes.com/city/hyderabad/as-caa-stir-rages-tricolour-supplies-hit/articleshow/73163026.cms',
#   'title': 'Hyderabad: As CAA stir rages, Tricolour supplies hit',
#   'date': '2020-01-09T01:08:08Z'},
#  {'url': 'https://timesofindia.indiatimes.com/city/agra/anti-caa-clashes-amu-students-file-petition-in-hc-for-investigation-into-police-role/articleshow/73162186.cms',
# ...
